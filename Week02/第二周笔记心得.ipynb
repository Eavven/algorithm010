# %% [markdown]
# #### 代码笔记
# #### 242.有效的字母异位词
#
# 想通过set来比较是否相等，但忽略了元素的个数，最后参考国际版题解通过dict和列表来比较，分别记录出现字母以及字母出现个数
# 另外最简单的直接排序后比较没想到

# %%
#如何比较set，参考https://medium.com/better-programming/a-visual-guide-to-set-comparisons-in-python-6ab7edb9ec41
set1 = set('hello')
set2 = set('lloeh')
c = set1.symmetric_difference(set2)
c == set()
# Out:
# True

# %% [markdown]
# #### 课堂笔记

# %% [markdown]
# ![image.png](attachment:image.png)
# 面试解题四件套，首先与面试官去讨论这道题目的各个细节，充分了解这个题目

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 养成总结代码的习惯，可以建立一个文档、github或者通过anki定期复习
